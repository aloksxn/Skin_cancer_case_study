# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
## If you are using the data by mounting the google drive, use the following :
## from google.colab import drive
## drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# !unzip -q "/content/gdrive/MyDrive/CNN_assignment.zip"
# Out:
# replace Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0010512.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/")
data_dir_test = pathlib.Path("/content/Skin cancer ISIC The International Skin Imaging Collaboration/Test/")

# %%
#Train Image count
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)

#Test Image count
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,batch_size=batch_size,image_size=(img_height,img_width),label_mode='categorical',seed=123,subset="training",validation_split=0.2)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds =tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,batch_size=batch_size,image_size=(img_height,img_width),label_mode='categorical',seed=123,subset="validation",validation_split=0.2)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

### your code goes here, you can use training or validation data to visualize
#Dictionary to store the path of image as per the class
import matplotlib.image as img
plt.figure(figsize=(10,10))
for i in range(9):
  plt.subplot(3, 3, i + 1)
  image = img.imread(str(list(data_dir_train.glob(class_names[i]+'/*.jpg'))[1]))
  plt.title(class_names[i])
  plt.imshow(image)

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here
input_shape = (img_height,img_width,3)

model = Sequential()    #Setting Sequential object

#First
model.add(layers.experimental.preprocessing.Rescaling(1./255,input_shape=input_shape))
model.add(layers.Conv2D(32,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Second Convolution Layer
model.add(layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Third Convolution Layer
model.add(layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

model.add(layers.Flatten())   #Keras.layers.flatten function flattens the multi-dimensional input tensors into a single dimension.

#Dense Layer
model.add(layers.Dense(512,activation='relu'))

#Dense Layer
model.add(layers.Dense(128,activation='relu'))

#Dense Layer with softmax activation function (output will be probabilities used for classification purpose)
model.add(layers.Dense(len(class_names),activation='softmax'))

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='Adam',
              loss="categorical_crossentropy",
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_3 (MaxPoolin  (None, 89, 89, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_4 (MaxPoolin  (None, 43, 43, 64)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_5 (MaxPoolin  (None, 20, 20, 128)       0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 51200)             0
#
#  dense_3 (Dense)             (None, 512)               26214912
#
#  dense_4 (Dense)             (None, 128)               65664
#
#  dense_5 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 26374985 (100.61 MB)
# Trainable params: 26374985 (100.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 23s 120ms/step - loss: 1.8975 - accuracy: 0.3092 - val_loss: 1.7616 - val_accuracy: 0.3758
# Epoch 2/20
# 56/56 [==============================] - 2s 42ms/step - loss: 1.5747 - accuracy: 0.4364 - val_loss: 1.5113 - val_accuracy: 0.4810
# Epoch 3/20
# 56/56 [==============================] - 2s 42ms/step - loss: 1.4064 - accuracy: 0.5100 - val_loss: 1.4536 - val_accuracy: 0.5324
# Epoch 4/20
# 56/56 [==============================] - 2s 42ms/step - loss: 1.3803 - accuracy: 0.5106 - val_loss: 1.3448 - val_accuracy: 0.5391
# Epoch 5/20
# 56/56 [==============================] - 3s 45ms/step - loss: 1.2761 - accuracy: 0.5592 - val_loss: 1.4216 - val_accuracy: 0.5235
# Epoch 6/20
# 56/56 [==============================] - 2s 44ms/step - loss: 1.1841 - accuracy: 0.5815 - val_loss: 1.3556 - val_accuracy: 0.5347
# Epoch 7/20
# 56/56 [==============================] - 2s 42ms/step - loss: 1.1267 - accuracy: 0.5898 - val_loss: 1.6110 - val_accuracy: 0.4989
# Epoch 8/20
# 56/56 [==============================] - 2s 42ms/step - loss: 1.0882 - accuracy: 0.6010 - val_loss: 1.3457 - val_accuracy: 0.5414
# Epoch 9/20
# 56/56 [==============================] - 2s 42ms/step - loss: 0.9562 - accuracy: 0.6512 - val_loss: 1.5469 - val_accuracy: 0.5145
# Epoch 10/20
# 56/56 [==============================] - 2s 42ms/step - loss: 0.8950 - accuracy: 0.6819 - val_loss: 1.4850 - val_accuracy: 0.5078
# Epoch 11/20
# 56/56 [==============================] - 2s 44ms/step - loss: 0.7823 - accuracy: 0.7171 - val_loss: 1.8050 - val_accuracy: 0.5302
# Epoch 12/20
# 56/56 [==============================] - 3s 47ms/step - loss: 0.6243 - accuracy: 0.7712 - val_loss: 1.7859 - val_accuracy: 0.5145
# Epoch 13/20
# 56/56 [==============================] - 2s 42ms/step - loss: 0.5662 - accuracy: 0.7963 - val_loss: 2.4091 - val_accuracy: 0.4340
# Epoch 14/20
# 56/56 [==============================] - 2s 42ms/step - loss: 0.6180 - accuracy: 0.7701 - val_loss: 2.1835 - val_accuracy: 0.5145
# Epoch 15/20
# 56/56 [==============================] - 2s 43ms/step - loss: 0.4382 - accuracy: 0.8331 - val_loss: 2.5141 - val_accuracy: 0.5145
# Epoch 16/20
# 56/56 [==============================] - 2s 43ms/step - loss: 0.3990 - accuracy: 0.8627 - val_loss: 2.4101 - val_accuracy: 0.4743
# Epoch 17/20
# 56/56 [==============================] - 2s 42ms/step - loss: 0.3311 - accuracy: 0.8756 - val_loss: 2.2987 - val_accuracy: 0.5168
# Epoch 18/20
# 56/56 [==============================] - 2s 42ms/step - loss: 0.2613 - accuracy: 0.8962 - val_loss: 2.7454 - val_accuracy: 0.5257
# Epoch 19/20
# 56/56 [==============================] - 2s 41ms/step - loss: 0.2175 - accuracy: 0.9113 - val_loss: 2.6587 - val_accuracy: 0.5078
# Epoch 20/20
# 56/56 [==============================] - 2s 42ms/step - loss: 0.2044 - accuracy: 0.9118 - val_loss: 2.5143 - val_accuracy: 0.4944

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here
# 1) Accuracy: Training accuracy is increasing while the validation accuracy is decreasing with epochs. This suggests that there maybe a overfitting proble,
# 2) Loss: As the loss is decreasing the validation loss is continuously increasing and hence will not reach a minima. This definitely confirms an overfitting issue.
#
# OVERFITTING PROBLEM : At last(20th Epoch) validation accuracy is ~50% and validation loss has an increasing trend with increasing epochs

# %%
class_names
# Out:
# ['actinic keratosis',
#  'basal cell carcinoma',
#  'dermatofibroma',
#  'melanoma',
#  'nevus',
#  'pigmented benign keratosis',
#  'seborrheic keratosis',
#  'squamous cell carcinoma',
#  'vascular lesion']

# %%
train_ds.take(1)
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 9), dtype=tf.float32, name=None))>

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy.
# Your code goes here
data_aug = keras.Sequential([
                             layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode='reflect')
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here
plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(data_aug(images)[i].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here
model2 = Sequential()                     #Sequential allows you to create models layer-by-layer
rescale = tf.keras.Sequential([
  #To rescale an input in the [0, 255] range to be in the [0, 1] range
  layers.experimental.preprocessing.Rescaling(1./255)
])
model2.add(data_aug)             #Augmentation layer
model2.add(rescale)               #Rescaling layer

#First Convolution Layer
model2.add(layers.Conv2D(32,kernel_size=(3,3),activation='relu'))
model2.add(layers.MaxPool2D(pool_size=(2,2)))

#Dropout layer with 25% Fraction of the input units to drop.
model2.add(layers.Dropout(0.25))

#Second Convolution Layer
model2.add(layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model2.add(layers.MaxPool2D(pool_size=(2,2)))

#Dropout layer with 25% Fraction of the input units to drop.
model2.add(layers.Dropout(0.25))

#Third Convolution Layer
model2.add(layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model2.add(layers.MaxPool2D(pool_size=(2,2)))

#Keras.layers.flatten function flattens the multi-dimensional input tensors into a single dimension.
model2.add(layers.Flatten())

#Dense Layer
model2.add(layers.Dense(512,activation='relu'))

#Dense Layer
model2.add(layers.Dense(128,activation='relu'))

#Dropout layer with 50% Fraction of the input units to drop.
model2.add(layers.Dropout(0.50))

#Dense Layer with softmax activation function.
#Softmax is an activation function that scales numbers/logits into probabilities.
model2.add(layers.Dense(len(class_names),activation='softmax'))

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model2.compile(optimizer='Adam',
              loss="categorical_crossentropy",
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
history = model2.fit(train_ds,epochs=epochs,validation_data=val_ds,verbose=1)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 8s 76ms/step - loss: 2.4490 - accuracy: 0.1875 - val_loss: 2.0686 - val_accuracy: 0.1924
# Epoch 2/20
# 56/56 [==============================] - 4s 67ms/step - loss: 2.0426 - accuracy: 0.2098 - val_loss: 2.0023 - val_accuracy: 0.2662
# Epoch 3/20
# 56/56 [==============================] - 4s 67ms/step - loss: 1.8683 - accuracy: 0.3225 - val_loss: 1.7758 - val_accuracy: 0.3423
# Epoch 4/20
# 56/56 [==============================] - 4s 69ms/step - loss: 1.7684 - accuracy: 0.3532 - val_loss: 1.6510 - val_accuracy: 0.4206
# Epoch 5/20
# 56/56 [==============================] - 4s 66ms/step - loss: 1.6522 - accuracy: 0.3917 - val_loss: 1.6180 - val_accuracy: 0.4251
# Epoch 6/20
# 56/56 [==============================] - 4s 65ms/step - loss: 1.6006 - accuracy: 0.4157 - val_loss: 1.6104 - val_accuracy: 0.4251
# Epoch 7/20
# 56/56 [==============================] - 4s 67ms/step - loss: 1.5619 - accuracy: 0.4448 - val_loss: 1.5363 - val_accuracy: 0.4877
# Epoch 8/20
# 56/56 [==============================] - 4s 69ms/step - loss: 1.5663 - accuracy: 0.4621 - val_loss: 1.5284 - val_accuracy: 0.4944
# Epoch 9/20
# 56/56 [==============================] - 3s 62ms/step - loss: 1.5129 - accuracy: 0.4760 - val_loss: 1.5092 - val_accuracy: 0.5190
# Epoch 10/20
# 56/56 [==============================] - 4s 64ms/step - loss: 1.4778 - accuracy: 0.4816 - val_loss: 1.5750 - val_accuracy: 0.4586
# Epoch 11/20
# 56/56 [==============================] - 4s 67ms/step - loss: 1.4515 - accuracy: 0.4967 - val_loss: 1.4759 - val_accuracy: 0.4676
# Epoch 12/20
# 56/56 [==============================] - 3s 62ms/step - loss: 1.4361 - accuracy: 0.4994 - val_loss: 1.5751 - val_accuracy: 0.4676
# Epoch 13/20
# 56/56 [==============================] - 3s 62ms/step - loss: 1.4252 - accuracy: 0.5100 - val_loss: 1.4837 - val_accuracy: 0.4497
# Epoch 14/20
# 56/56 [==============================] - 4s 63ms/step - loss: 1.3954 - accuracy: 0.5173 - val_loss: 1.5479 - val_accuracy: 0.4653
# Epoch 15/20
# 56/56 [==============================] - 3s 62ms/step - loss: 1.3925 - accuracy: 0.5273 - val_loss: 1.5874 - val_accuracy: 0.4541
# Epoch 16/20
# 56/56 [==============================] - 4s 65ms/step - loss: 1.3883 - accuracy: 0.5179 - val_loss: 1.5172 - val_accuracy: 0.4653
# Epoch 17/20
# 56/56 [==============================] - 4s 63ms/step - loss: 1.3391 - accuracy: 0.5223 - val_loss: 1.4899 - val_accuracy: 0.4765
# Epoch 18/20
# 56/56 [==============================] - 4s 63ms/step - loss: 1.3017 - accuracy: 0.5413 - val_loss: 1.5101 - val_accuracy: 0.4855
# Epoch 19/20
# 56/56 [==============================] - 4s 67ms/step - loss: 1.3255 - accuracy: 0.5480 - val_loss: 1.4477 - val_accuracy: 0.4855
# Epoch 20/20
# 56/56 [==============================] - 4s 64ms/step - loss: 1.3421 - accuracy: 0.5402 - val_loss: 1.4099 - val_accuracy: 0.5213

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?
#
# ###**Observation : There is improvement in the form of reduction in overfit in the model. One can see that the Validation loss is decreasing and may reach the minima if allowed to train further (more Epochs). Accuracy for both train and test show increasing trend.**

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.

path_list=[]
lesion_list=[]
for i in class_names:

    for j in data_dir_train.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])

# %%
count=[]
for i in class_names:
    count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(25,10))
plt.bar(class_names,count)
plt.show()

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
#   ### **Ans : Seborrheic Keratosis**
# #### - Which classes dominate the data in terms proportionate number of samples?
#   ### **Ans : Pigmented Benign Keratosis , Melanoma and Basal Cell Carcinoma**

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (9.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.2)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.25.2)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="/content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x79D4C0AEA4D0>: 100%|██████████| 500/500 [00:15<00:00, 31.32 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x79D4BF7CB4F0>: 100%|██████████| 500/500 [00:16<00:00, 30.96 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x79D4BCD36080>: 100%|██████████| 500/500 [00:15<00:00, 32.46 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=2313x1985 at 0x79D5204B1A80>: 100%|██████████| 500/500 [01:23<00:00,  6.00 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1019x717 at 0x79D4C01983A0>: 100%|██████████| 500/500 [01:16<00:00,  6.53 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x79D533F957B0>: 100%|██████████| 500/500 [00:16<00:00, 29.71 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x79D5204B1A80>: 100%|██████████| 500/500 [00:36<00:00, 13.70 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x79D5C900D600>: 100%|██████████| 500/500 [00:15<00:00, 33.15 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x79D533F96530>: 100%|██████████| 500/500 [00:15<00:00, 31.51 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
from glob import glob
path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df2)
# Out:
# <ipython-input-60-17a6b079869a>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = original_df.append(df2)

# %%
new_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    962
# melanoma                      938
# basal cell carcinoma          876
# nevus                         857
# squamous cell carcinoma       681
# vascular lesion               639
# actinic keratosis             614
# dermatofibroma                595
# seborrheic keratosis          577
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
data_dir_train="/content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),label_mode='categorical',batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),label_mode='categorical',
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
#Model

model3 = Sequential()

model3.add(rescale)   #Rescaling Layer

#First Convolution layer
model3.add(layers.Conv2D(32,kernel_size=(2,2),activation='relu'))
model3.add(layers.MaxPool2D(pool_size=(2,2)))
model3.add(layers.Dropout(0.25))

#Second Convolution Layer
model3.add(layers.Conv2D(64,kernel_size=(2,2),activation='relu'))
model3.add(layers.MaxPool2D(pool_size=(2,2)))
model3.add(layers.Dropout(0.25))

#Third Convolution Layer
model3.add(layers.Conv2D(128,kernel_size=(2,2),activation='relu'))
model3.add(layers.MaxPool2D(pool_size=(2,2)))

#Flatten Layer
model3.add(layers.Flatten())

#Dense Layer
model3.add(layers.Dense(512,activation='relu'))

#Dropout layer
model3.add(layers.Dropout(0.25))

model3.add(layers.BatchNormalization())

#Dense Layer
model3.add(layers.Dense(128,activation='relu'))

#Dropout layer with 50% Fraction of the input units to drop.
model3.add(layers.Dropout(0.50))

#Batch normalization
model3.add(layers.BatchNormalization())

#Dense layer with Softmax activation function.
model3.add(layers.Dense(len(class_names),activation='softmax'))

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
model3.compile(optimizer='Adam',
              loss="categorical_crossentropy",
              metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 50
## Your code goes here, use 50 epochs.
history = model3.fit(train_ds,epochs=epochs,validation_data=val_ds,verbose=1)
# Out:
# Epoch 1/50
# 169/169 [==============================] - 36s 175ms/step - loss: 2.4751 - accuracy: 0.1769 - val_loss: 4.1325 - val_accuracy: 0.1715
# Epoch 2/50
# 169/169 [==============================] - 29s 170ms/step - loss: 1.8905 - accuracy: 0.2988 - val_loss: 2.1306 - val_accuracy: 0.2784
# Epoch 3/50
# 169/169 [==============================] - 28s 160ms/step - loss: 1.6577 - accuracy: 0.3744 - val_loss: 2.7528 - val_accuracy: 0.3051
# Epoch 4/50
# 169/169 [==============================] - 29s 166ms/step - loss: 1.5648 - accuracy: 0.4086 - val_loss: 1.7153 - val_accuracy: 0.3756
# Epoch 5/50
# 169/169 [==============================] - 28s 162ms/step - loss: 1.4792 - accuracy: 0.4373 - val_loss: 1.5356 - val_accuracy: 0.4068
# Epoch 6/50
# 169/169 [==============================] - 30s 172ms/step - loss: 1.4487 - accuracy: 0.4497 - val_loss: 1.5891 - val_accuracy: 0.4016
# Epoch 7/50
# 169/169 [==============================] - 29s 166ms/step - loss: 1.3886 - accuracy: 0.4688 - val_loss: 1.3872 - val_accuracy: 0.4410
# Epoch 8/50
# 169/169 [==============================] - 29s 166ms/step - loss: 1.2961 - accuracy: 0.5067 - val_loss: 1.2768 - val_accuracy: 0.5108
# Epoch 9/50
# 169/169 [==============================] - 29s 168ms/step - loss: 1.2385 - accuracy: 0.5289 - val_loss: 1.3339 - val_accuracy: 0.4840
# Epoch 10/50
# 169/169 [==============================] - 29s 167ms/step - loss: 1.2029 - accuracy: 0.5566 - val_loss: 1.2097 - val_accuracy: 0.5397
# Epoch 11/50
# 169/169 [==============================] - 29s 169ms/step - loss: 1.1323 - accuracy: 0.5788 - val_loss: 1.2234 - val_accuracy: 0.5360
# Epoch 12/50
# 169/169 [==============================] - 29s 170ms/step - loss: 1.0557 - accuracy: 0.6081 - val_loss: 1.1557 - val_accuracy: 0.5479
# Epoch 13/50
# 169/169 [==============================] - 28s 164ms/step - loss: 0.9911 - accuracy: 0.6287 - val_loss: 1.0819 - val_accuracy: 0.5561
# Epoch 14/50
# 169/169 [==============================] - 30s 171ms/step - loss: 0.9918 - accuracy: 0.6282 - val_loss: 1.1796 - val_accuracy: 0.5553
# Epoch 15/50
# 169/169 [==============================] - 29s 162ms/step - loss: 0.8570 - accuracy: 0.6821 - val_loss: 0.9660 - val_accuracy: 0.6184
# Epoch 16/50
# 169/169 [==============================] - 29s 168ms/step - loss: 0.8312 - accuracy: 0.6860 - val_loss: 1.0093 - val_accuracy: 0.6065
# Epoch 17/50
# 169/169 [==============================] - 29s 168ms/step - loss: 0.8133 - accuracy: 0.6999 - val_loss: 0.8698 - val_accuracy: 0.6689
# Epoch 18/50
# 169/169 [==============================] - 28s 159ms/step - loss: 0.7270 - accuracy: 0.7316 - val_loss: 1.0080 - val_accuracy: 0.6303
# Epoch 19/50
# 169/169 [==============================] - 28s 162ms/step - loss: 0.7100 - accuracy: 0.7455 - val_loss: 0.8005 - val_accuracy: 0.6919
# Epoch 20/50
# 169/169 [==============================] - 28s 159ms/step - loss: 0.6639 - accuracy: 0.7611 - val_loss: 0.7361 - val_accuracy: 0.7261
# Epoch 21/50
# 169/169 [==============================] - 28s 161ms/step - loss: 0.6088 - accuracy: 0.7739 - val_loss: 0.7885 - val_accuracy: 0.6971
# Epoch 22/50
# 169/169 [==============================] - 28s 163ms/step - loss: 0.5131 - accuracy: 0.8160 - val_loss: 0.7346 - val_accuracy: 0.7283
# Epoch 23/50
# 169/169 [==============================] - 29s 166ms/step - loss: 0.5138 - accuracy: 0.8218 - val_loss: 0.7114 - val_accuracy: 0.7275
# Epoch 24/50
# 169/169 [==============================] - 30s 167ms/step - loss: 0.4495 - accuracy: 0.8320 - val_loss: 0.8036 - val_accuracy: 0.7060
# Epoch 25/50
# 169/169 [==============================] - 30s 175ms/step - loss: 0.4691 - accuracy: 0.8262 - val_loss: 0.9560 - val_accuracy: 0.6667
# Epoch 26/50
# 169/169 [==============================] - 28s 160ms/step - loss: 0.4733 - accuracy: 0.8281 - val_loss: 0.6468 - val_accuracy: 0.7520
# Epoch 27/50
# 169/169 [==============================] - 29s 167ms/step - loss: 0.4191 - accuracy: 0.8442 - val_loss: 0.6687 - val_accuracy: 0.7558
# Epoch 28/50
# 169/169 [==============================] - 29s 165ms/step - loss: 0.4387 - accuracy: 0.8433 - val_loss: 0.6709 - val_accuracy: 0.7550
# Epoch 29/50
# 169/169 [==============================] - 28s 162ms/step - loss: 0.3694 - accuracy: 0.8657 - val_loss: 0.5877 - val_accuracy: 0.7840
# Epoch 30/50
# 169/169 [==============================] - 28s 161ms/step - loss: 0.4341 - accuracy: 0.8448 - val_loss: 0.6770 - val_accuracy: 0.7461
# Epoch 31/50
# 169/169 [==============================] - 28s 159ms/step - loss: 0.6614 - accuracy: 0.7832 - val_loss: 0.5770 - val_accuracy: 0.7951
# Epoch 32/50
# 169/169 [==============================] - 28s 159ms/step - loss: 0.3841 - accuracy: 0.8589 - val_loss: 0.5324 - val_accuracy: 0.7981
# Epoch 33/50
# 169/169 [==============================] - 35s 197ms/step - loss: 0.3473 - accuracy: 0.8694 - val_loss: 0.5049 - val_accuracy: 0.8055
# Epoch 34/50
# 169/169 [==============================] - 28s 159ms/step - loss: 0.3987 - accuracy: 0.8557 - val_loss: 0.5789 - val_accuracy: 0.7899
# Epoch 35/50
# 169/169 [==============================] - 28s 162ms/step - loss: 0.3030 - accuracy: 0.8880 - val_loss: 0.5535 - val_accuracy: 0.7996
# Epoch 36/50
# 169/169 [==============================] - 29s 166ms/step - loss: 0.3176 - accuracy: 0.8865 - val_loss: 0.5009 - val_accuracy: 0.8151
# Epoch 37/50
# 169/169 [==============================] - 28s 161ms/step - loss: 0.3613 - accuracy: 0.8650 - val_loss: 0.5294 - val_accuracy: 0.8025
# Epoch 38/50
# 169/169 [==============================] - 28s 162ms/step - loss: 0.2868 - accuracy: 0.8926 - val_loss: 0.5201 - val_accuracy: 0.8010
# Epoch 39/50
# 169/169 [==============================] - 35s 200ms/step - loss: 0.2853 - accuracy: 0.8997 - val_loss: 0.5298 - val_accuracy: 0.8092
# Epoch 40/50
# 169/169 [==============================] - 29s 167ms/step - loss: 0.3196 - accuracy: 0.8817 - val_loss: 0.4457 - val_accuracy: 0.8456
# Epoch 41/50
# 169/169 [==============================] - 29s 166ms/step - loss: 0.2550 - accuracy: 0.9028 - val_loss: 0.6251 - val_accuracy: 0.7795
# Epoch 42/50
# 169/169 [==============================] - 28s 159ms/step - loss: 0.2426 - accuracy: 0.9110 - val_loss: 0.5592 - val_accuracy: 0.8107
# Epoch 43/50
# 169/169 [==============================] - 29s 165ms/step - loss: 0.2415 - accuracy: 0.9067 - val_loss: 0.4843 - val_accuracy: 0.8344
# Epoch 44/50
# 169/169 [==============================] - 28s 160ms/step - loss: 0.2345 - accuracy: 0.9125 - val_loss: 0.5374 - val_accuracy: 0.8114
# Epoch 45/50
# 169/169 [==============================] - 28s 159ms/step - loss: 0.2247 - accuracy: 0.9121 - val_loss: 0.5311 - val_accuracy: 0.8114
# Epoch 46/50
# 169/169 [==============================] - 33s 190ms/step - loss: 0.2543 - accuracy: 0.9104 - val_loss: 1.3280 - val_accuracy: 0.6667
# Epoch 47/50
# 169/169 [==============================] - 29s 165ms/step - loss: 0.4053 - accuracy: 0.8654 - val_loss: 0.6098 - val_accuracy: 0.7877
# Epoch 48/50
# 169/169 [==============================] - 28s 160ms/step - loss: 0.2572 - accuracy: 0.9054 - val_loss: 0.8779 - val_accuracy: 0.8025
# Epoch 49/50
# 169/169 [==============================] - 29s 170ms/step - loss: 0.2177 - accuracy: 0.9171 - val_loss: 0.5474 - val_accuracy: 0.8218
# Epoch 50/50
# 169/169 [==============================] - 28s 160ms/step - loss: 0.1988 - accuracy: 0.9253 - val_loss: 0.5904 - val_accuracy: 0.8018

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?
#
# ## **OBSERVATION**
#
# ## Validation and training accuracy are both showing an increasing trend. Similar case for the training and validation Loss.
#
# ## Class rebalance has helped further to reduce the overfit and improve the accuracy. Also Increasing the Epochs to 50  which mean more training has improved the accuracy and lower both the loss as opposed to 20 epochs
#
# ## Validation Accuracy achieved ~ 80 %. Further optimising the number of Epochs so we can achieve minimum loss can help.
